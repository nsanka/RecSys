# %%
import os 
import sys 
import time 
import glob 
import sqlite3
import datetime 
import numpy as np
import pandas as pd

# %%
# This code will retrieve all Million Song Dataset and save to a .csv file
# You will need to get the H5 Files and Getters from the Shared Drive First

# %%
# path to the Million Song Dataset subset (uncompressed) 
# CHANGE IT TO YOUR LOCAL CONFIGURATION 
msd_subset_path='/Users/dave/Documents/GitHub/Dave-Hdz/MADS_Capstone'
msd_subset_data_path=os.path.join(msd_subset_path,'data')
msd_subset_addf_path=os.path.join(msd_subset_path,'AdditionalFiles') 
# assert os.path.isdir(msd_subset_path),'wrong path' # sanity check

# path to the Million Song Dataset code # CHANGE IT TO YOUR LOCAL CONFIGURATION
msd_code_path='/Users/dave/Documents/GitHub/Dave-Hdz/MADS_Capstone/MSongsDB'
assert os.path.isdir(msd_code_path),'wrong path' # sanity check

# we add some paths to python so we can import MSD code
# Ubuntu: you can change the environment variable PYTHONPATH # in your .bashrc file so you do not have to type these lines
sys.path.append( os.path.join(msd_code_path,'PythonSrc')) # imports specific to the MSD

import hdf5_getters as GETTERS

# %%
# the following function simply gives us a nice string for
# a time lag in seconds
def strtimedelta(starttime ,stoptime):
    return str(datetime.timedelta(seconds=stoptime -starttime))

# %%
# we define this very useful function to iterate the files
def apply_to_all_files(basedir ,func=lambda x: x,ext='.h5'): 
    """
    From a base directory , go through all subdirectories , find all files with the given extension, apply the
    given function ’func’ to all of them.
    If no ’func’ is passed, we do nothing except counting. INPUT
    basedir - base directory of the dataset
    func - function to apply to all filenames ext - extension , .h5 by default
    RETURN
    number of files
    """
    cnt=0
    # iterate over all files in all subdirectories
    for root, dirs , files in os.walk(basedir):
        files = glob.glob(os.path.join(root,'*'+ext)) 
        # count files
        cnt += len(files)
        # apply function to all files
        for f in files:
            func(f)
    return cnt

# we can now easily count the number of files in the dataset
print ('number of song files : ', apply_to_all_files(msd_subset_data_path))
# Out:
# number of song files :  10000

# %%
num_songs = []
artist_familiarity = []
artist_hotttnesss = []
artist_id = []
artist_mbid = []
artist_playmeid = []
artist_7digitalid = []
artist_latitude = []
artist_longitude = []
artist_location = []
artist_name = []
release = []
release_7digitalid = []
song_id = []
song_hotttnesss = []
title = []
track_7digitalid = []
similar_artists = []
artist_terms = []
artist_terms_freq = []
artist_terms_weight = []
analysis_sample_rate = []
audio_md5 = []
danceability = []
duration = []
end_of_fade_in = []
energy = []
key = []
key_confidence = []
loudness = []
mode = []
mode_confidence = []
start_of_fade_out = []
tempo = []
time_signature = []
time_signature_confidence = []
track_id = []
segments_start = []
segments_confidence = []
segments_pitches = []
segments_timbre = []
segments_loudness_max = []
segments_loudness_max_time = []
segments_loudness_start = []
sections_start = []
sections_confidence = []
beats_start = []
beats_confidence = []
bars_start = []
bars_confidence = []
tatums_start = []
tatums_confidence = []
artist_mbtags = []
artist_mbtags_count = []
year = []

# %%
Getters = ['get_num_songs','get_artist_familiarity','get_artist_hotttnesss','get_artist_id','get_artist_mbid',
           'get_artist_playmeid','get_artist_7digitalid','get_artist_latitude','get_artist_longitude',
           'get_artist_location','get_artist_name','get_release','get_release_7digitalid','get_song_id',
           'get_song_hotttnesss','get_title','get_track_7digitalid','get_similar_artists','get_artist_terms',
           'get_artist_terms_freq','get_artist_terms_weight','get_analysis_sample_rate','get_audio_md5',
           'get_danceability','get_duration','get_end_of_fade_in','get_energy','get_key','get_key_confidence',
           'get_loudness','get_mode','get_mode_confidence','get_start_of_fade_out','get_tempo','get_time_signature',
           'get_time_signature_confidence','get_track_id','get_segments_start','get_segments_confidence',
           'get_segments_pitches','get_segments_timbre','get_segments_loudness_max','get_segments_loudness_max_time',
           'get_segments_loudness_start','get_sections_start','get_sections_confidence','get_beats_start',
           'get_beats_confidence','get_bars_start','get_bars_confidence','get_tatums_start','get_tatums_confidence',
           'get_artist_mbtags','get_artist_mbtags_count','get_year']

# %%
Getters = [('get_num_songs', num_songs), ('get_artist_familiarity', artist_familiarity), 
           ('get_artist_hotttnesss', artist_hotttnesss), ('get_artist_id', artist_id), 
           ('get_artist_mbid', artist_mbid), ('get_artist_playmeid', artist_playmeid), 
           ('get_artist_7digitalid', artist_7digitalid), ('get_artist_latitude', artist_latitude), 
           ('get_artist_longitude', artist_longitude), ('get_artist_location', artist_location), 
           ('get_artist_name', artist_name), ('get_release', release), 
           ('get_release_7digitalid', release_7digitalid), ('get_song_id', song_id), 
           ('get_song_hotttnesss', song_hotttnesss), ('get_title', title), 
           ('get_track_7digitalid', track_7digitalid), ('get_similar_artists', similar_artists), 
           ('get_artist_terms', artist_terms), ('get_artist_terms_freq', artist_terms_freq), 
           ('get_artist_terms_weight', artist_terms_weight), ('get_analysis_sample_rate', analysis_sample_rate), 
           ('get_audio_md5', audio_md5), ('get_danceability', danceability), ('get_duration', duration), 
           ('get_end_of_fade_in', end_of_fade_in), ('get_energy', energy), ('get_key', key), 
           ('get_key_confidence', key_confidence), ('get_loudness', loudness), ('get_mode', mode), 
           ('get_mode_confidence', mode_confidence), ('get_start_of_fade_out', start_of_fade_out), 
           ('get_tempo', tempo), ('get_time_signature', time_signature), 
           ('get_time_signature_confidence', time_signature_confidence), ('get_track_id', track_id), 
           ('get_segments_start', segments_start), ('get_segments_confidence', segments_confidence), 
           ('get_segments_pitches', segments_pitches), ('get_segments_timbre', segments_timbre), 
           ('get_segments_loudness_max', segments_loudness_max), 
           ('get_segments_loudness_max_time', segments_loudness_max_time), 
           ('get_segments_loudness_start', segments_loudness_start), ('get_sections_start', sections_start), 
           ('get_sections_confidence', sections_confidence), ('get_beats_start', beats_start), 
           ('get_beats_confidence', beats_confidence), ('get_bars_start', bars_start), 
           ('get_bars_confidence', bars_confidence), ('get_tatums_start', tatums_start), 
           ('get_tatums_confidence', tatums_confidence), ('get_artist_mbtags', artist_mbtags), 
           ('get_artist_mbtags_count', artist_mbtags_count), ('get_year', year)]

# %%
# let’s now get all artist names in a set(). One nice property: 
# if we enter many times the same artist, only one will be kept.
all_artist_names = []
all_titles = set()

# we define the function to apply to all files
def func_to_get_info(filename):
    """
    This function does 3 simple things : 
    - open the song file
    - get artist ID and put it
    - close the file
    """
    h5 = GETTERS.open_h5_file_read(filename) 
    
    num_songs.append(GETTERS.get_num_songs(h5))
    artist_familiarity.append(GETTERS.get_artist_familiarity(h5))
    artist_hotttnesss.append(GETTERS.get_artist_hotttnesss(h5))
    artist_id.append(GETTERS.get_artist_id(h5))
    artist_mbid.append(GETTERS.get_artist_mbid(h5))
    artist_playmeid.append(GETTERS.get_artist_playmeid(h5))
    artist_7digitalid.append(GETTERS.get_artist_7digitalid(h5))
    artist_latitude.append(GETTERS.get_artist_latitude(h5))
    artist_longitude.append(GETTERS.get_artist_longitude(h5))
    artist_location.append(GETTERS.get_artist_location(h5))
    artist_name.append(GETTERS.get_artist_name(h5))
    release.append(GETTERS.get_release(h5))
    release_7digitalid.append(GETTERS.get_release_7digitalid(h5))
    song_id.append(GETTERS.get_song_id(h5))
    song_hotttnesss.append(GETTERS.get_song_hotttnesss(h5))
    title.append(GETTERS.get_title(h5))
    track_7digitalid.append(GETTERS.get_track_7digitalid(h5))
    similar_artists.append(GETTERS.get_similar_artists(h5))
    artist_terms.append(GETTERS.get_artist_terms(h5))
    artist_terms_freq.append(GETTERS.get_artist_terms_freq(h5))
    artist_terms_weight.append(GETTERS.get_artist_terms_weight(h5))
    analysis_sample_rate.append(GETTERS.get_analysis_sample_rate(h5))
    audio_md5.append(GETTERS.get_audio_md5(h5))
    danceability.append(GETTERS.get_danceability(h5))
    duration.append(GETTERS.get_duration(h5))
    end_of_fade_in.append(GETTERS.get_end_of_fade_in(h5))
    energy.append(GETTERS.get_energy(h5))
    key.append(GETTERS.get_key(h5))
    key_confidence.append(GETTERS.get_key_confidence(h5))
    loudness.append(GETTERS.get_loudness(h5))
    mode.append(GETTERS.get_mode(h5))
    mode_confidence.append(GETTERS.get_mode_confidence(h5))
    start_of_fade_out.append(GETTERS.get_start_of_fade_out(h5))
    tempo.append(GETTERS.get_tempo(h5))
    time_signature.append(GETTERS.get_time_signature(h5))
    time_signature_confidence.append(GETTERS.get_time_signature_confidence(h5))
    track_id.append(GETTERS.get_track_id(h5))
    segments_start.append(GETTERS.get_segments_start(h5))
    segments_confidence.append(GETTERS.get_segments_confidence(h5))
    segments_pitches.append(GETTERS.get_segments_pitches(h5))
    segments_timbre.append(GETTERS.get_segments_timbre(h5))
    segments_loudness_max.append(GETTERS.get_segments_loudness_max(h5))
    segments_loudness_max_time.append(GETTERS.get_segments_loudness_max_time(h5))
    segments_loudness_start.append(GETTERS.get_segments_loudness_start(h5))
    sections_start.append(GETTERS.get_sections_start(h5))
    sections_confidence.append(GETTERS.get_sections_confidence(h5))
    beats_start.append(GETTERS.get_beats_start(h5))
    beats_confidence.append(GETTERS.get_beats_confidence(h5))
    bars_start.append(GETTERS.get_bars_start(h5))
    bars_confidence.append(GETTERS.get_bars_confidence(h5))
    tatums_start.append(GETTERS.get_tatums_start(h5))
    tatums_confidence.append(GETTERS.get_tatums_confidence(h5))
    artist_mbtags.append(GETTERS.get_artist_mbtags(h5))
    artist_mbtags_count.append(GETTERS.get_artist_mbtags_count(h5))
    year.append(GETTERS.get_year(h5))

    h5.close()
    
    
# let’s apply the previous function to all files # we’ll also measure how long it takes
t1 = time.time()
apply_to_all_files(msd_subset_data_path,func=func_to_get_info)
t2 = time.time()
print ('all data extracted in: ', strtimedelta(t1,t2))
# Out:
# all data extracted in:  0:09:24.128459

# %%
df = pd.DataFrame({'num_songs': num_songs, 'artist_familiarity': artist_familiarity, 
              'artist_hotttnesss': artist_hotttnesss, 'artist_id': artist_id, 'artist_mbid': artist_mbid, 
              'artist_playmeid': artist_playmeid, 'artist_7digitalid': artist_7digitalid, 
              'artist_latitude': artist_latitude, 'artist_longitude': artist_longitude, 
              'artist_location': artist_location, 'artist_name': artist_name, 'release': release, 
              'release_7digitalid': release_7digitalid, 'song_id': song_id, 'song_hotttnesss': song_hotttnesss, 
              'title': title, 'track_7digitalid': track_7digitalid, 'similar_artists': similar_artists, 
              'artist_terms': artist_terms, 'artist_terms_freq': artist_terms_freq, 
              'artist_terms_weight': artist_terms_weight, 'analysis_sample_rate': analysis_sample_rate, 
              'audio_md5': audio_md5, 'danceability': danceability, 'duration': duration, 
              'end_of_fade_in': end_of_fade_in, 'energy': energy, 'key': key, 'key_confidence': key_confidence, 
              'loudness': loudness, 'mode': mode, 'mode_confidence': mode_confidence, 
              'start_of_fade_out': start_of_fade_out, 'tempo': tempo, 'time_signature': time_signature, 
              'time_signature_confidence': time_signature_confidence, 'track_id': track_id, 
              'segments_start': segments_start, 'segments_confidence': segments_confidence, 
              'segments_pitches': segments_pitches, 'segments_timbre': segments_timbre, 
              'segments_loudness_max': segments_loudness_max, 
              'segments_loudness_max_time': segments_loudness_max_time, 
              'segments_loudness_start': segments_loudness_start, 'sections_start': sections_start, 
              'sections_confidence': sections_confidence, 'beats_start': beats_start, 
              'beats_confidence': beats_confidence, 'bars_start': bars_start, 'bars_confidence': bars_confidence, 
              'tatums_start': tatums_start, 'tatums_confidence': tatums_confidence, 'artist_mbtags': artist_mbtags,
              'artist_mbtags_count': artist_mbtags_count, 'year': year, })

# %%
# Convert object columns in UTF8 to string
obj_columns = ['artist_id', 'artist_mbid', 'artist_location', 'artist_name', 'release', 'song_id', 'title', 
               'audio_md5', 'track_id']

for col in obj_columns:
    df[col] = df[col].str.decode('utf-8')

# %%
df.to_csv('data/MSD_Sample.csv', index=False)
