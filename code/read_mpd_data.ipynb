# %%
import os
import re
import sys
import json
import fnmatch
import spotipy
import pandas as pd
import sqlite3
from sqlite3 import Error
from tqdm import tqdm
from zipfile import ZipFile
from datetime import datetime
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

# %%
cwd = os.getcwd()
sys.path.insert(1, os.path.join(cwd, '..'))
import config
# Spotify credentials
os.environ["SPOTIPY_CLIENT_ID"] = config.SPOTIPY_CLIENT_ID
os.environ["SPOTIPY_CLIENT_SECRET"] = config.SPOTIPY_CLIENT_SECRET
os.environ['SPOTIPY_REDIRECT_URI'] = config.SPOTIPY_REDIRECT_URI

# %%
def loop_slices(path, num_slices=20):
    cnt = 0
    mpd_playlists = []
    filenames = os.listdir(path)

    for fname in sorted(filenames):
        print(fname)
        if fname.startswith("mpd.slice.") and fname.endswith(".json"):
            cnt += 1
            fullpath = os.sep.join((path, fname))
            f = open(fullpath)
            js = f.read()
            f.close()
            current_slice = json.loads(js)

            # Create a list of all playlists
            for playlist in current_slice['playlists']:
                mpd_playlists.append(playlist)

            if cnt == num_slices:
                break
    return mpd_playlists

# Path where the json files are extracted
path = 'data/'
playlists = loop_slices(path, num_slices=20)

# %%
sp = spotipy.Spotify(client_credentials_manager = SpotifyClientCredentials())

cols_to_keep = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']

dfs = []
for playlist in tqdm(playlists):
   audio_feats = []
   for track in playlist['tracks']:
      track_uri = track['track_uri'].split(":")[2]
      feature = sp.audio_features(track_uri)
      if feature:
         audio_feats.append(feature[0])
   avg_feats = pd.DataFrame(audio_feats)[cols_to_keep].mean()
   avg_feats['name'] = playlist['name']
   avg_feats['pid'] = playlist['pid']
   dfs.append(avg_feats.T)

# %%
def loop_slices_zip(zip_file, num_slices=20):
    #print("Number of processors: ", mp.cpu_count())
    with ZipFile(zip_file) as zipfiles:
        file_list = zipfiles.namelist()

        #get only the csv files
        json_files = fnmatch.filter(file_list, "*.json")
        json_files_ex = fnmatch.filter(file_list, "*MACOSX*")
        json_files = set(json_files) - set(json_files_ex)
        json_files = [f for i,f in sorted([(int(fn.split('.')[2].split('-')[0]), fn) for fn in json_files])]
        print(json_files[:5])

        cnt = 0
        mpd_playlists = []
        for filename in tqdm(json_files):
            cnt+=1
            with zipfiles.open(filename) as json_file:
                current_slice = json.loads(json_file.read())
                
                # Create a list of all playlists
                for playlist in current_slice['playlists']:
                    mpd_playlists.append(playlist)

                if cnt == num_slices:
                    break
        return mpd_playlists

# %%
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Start Time =", current_time)

cols_to_keep = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 
                'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']
dfs = []

for playlist in tqdm(playlists):
    audio_feats = []
    all_uris_in_plylst = []
    for track in playlist['tracks']:
        uri = track['track_uri'].split("k:")[1]
        all_uris_in_plylst.append(uri)
    #print('pid : ', playlist['pid'])

    chunks_uris = [all_uris_in_plylst[i:i + 100] for i in range(0, len(all_uris_in_plylst), 100)]
    for chunk in  chunks_uris:
        for attempt in range(10):
            try:
                chunk_audio_feats = sp.audio_features(chunk)
                audio_feats.append(chunk_audio_feats)
            except Exception as e: 
                print(e)
                print('playlist: {}, chunk: {}'.format(playlist['name'], chunk))
            else:
                break
        else:
            print('Everything failed')
    
    playlist_audio_feats = [item for sublist in audio_feats for item in sublist]
    name = playlist['name']
    pid = playlist['pid']
    s1 = pd.Series([name, pid], index=['name', 'pid'])
    try: # Try/Except for when there is a None in playlist
        s2 = pd.DataFrame(playlist_audio_feats)[cols_to_keep].mean()
    except:
        print('Playlist "{}" has a None. PID: {}'.format(name, pid))
        s2 = pd.DataFrame([i for i in playlist_audio_feats if i])[cols_to_keep].mean() # List comprehension to remove None from list

    dfs.append(pd.DataFrame(s1.append(s2)).T)

# %%
def write_log(text):
    with open(log_file, 'a') as lf:
        lf.write(str(text) + '\n')

def get_playlist(conn, pid):
    """
    Query playlists by pid
    :param conn: the Connection object
    :param pid:
    :return: playlist
    """
    cur = conn.cursor()
    cur.execute("SELECT * FROM playlists WHERE pid=?", (pid,))
    rows = cur.fetchall()
    playlist = None
    if len(rows) > 0:
        playlist = rows[0]        
    return playlist

def select_track_by_trackuri(conn, track_uri):
    """
    Query tracks by track_uri
    :param conn: the Connection object
    :param track_uri:
    :return: track_id
    """
    cur = conn.cursor()
    cur.execute("SELECT track_id FROM tracks WHERE track_uri=?", (track_uri,))
    rows = cur.fetchall()
    track_id = 0
    if len(rows) > 0:
        track_id = rows[0][0]        
    return track_id

# This function takes somuch time because of loops, so didn't use it
def process_json_data_loop(conn, zip_file, filename, num_playlists, max_track_id):
    print('File: ' + filename)
    write_log('File: ' + filename)

    playlists = []
    ratings = []
    tracks = []
    cnt = 0
    with ZipFile(zip_file) as zipfiles:
        with zipfiles.open(filename) as json_file:
            json_data = json.loads(json_file.read())
            for playlist in json_data['playlists']:
                pl = get_playlist(conn, playlist['pid'])
                if pl != None:
                    write_log('Playlist already exists in database: ' + str(playlist['pid']))
                    print('Playlist already exists in database: ' + str(playlist['pid']))
                    # Playlist already exists in table
                    continue
                else:
                    write_log('Processing Playlist pid: ' + str(playlist['pid']))
                    print('Processing Playlist pid: ' + str(playlist['pid']))
                cnt += 1
                new_playlist = [playlist['pid'], playlist['name'], playlist['num_albums'], playlist['num_artists'], playlist['num_edits'], 
                                playlist['num_tracks'], playlist['collaborative'], playlist['duration_ms'], playlist['modified_at']]
                playlists.append(new_playlist)

                for track in playlist['tracks']:
                    track_uri = track['track_uri'].split(':')[2]
                    write_log('Processing Track: ' + track_uri)
                    # Check if track_uri exists in the tracks list
                    track_id = next((t[0] for t in tracks if track_uri in t), None)
                    if not track_id:
                        write_log('Track not found in tracks list: ' + track_uri)
                        # Check track_uri exists in the database
                        track_id = select_track_by_trackuri(conn, track_uri)
                        if track_id == 0:
                            write_log('Track not found in database: ' + track_uri)
                            album_uri = track['album_uri'].split(':')[2]
                            artist_uri = track['artist_uri'].split(':')[2]
                            # (max_track_id + 1) tracks already exist in database
                            track_id = len(tracks) + (max_track_id + 1)
                            new_track = [track_id, track['track_name'], track_uri, track['album_name'], album_uri, track['artist_name'], artist_uri]
                            write_log('Adding Track to database: ' + str(track_id))
                            tracks.append(new_track)
                    
                    new_rating = [playlist['pid'], track_id, track['pos'], playlist['num_followers']]
                    write_log('Adding Rating for pid:' + str(playlist['pid']) + ' track_id: ' + str(track_id))
                    ratings.append(new_rating)

                if (cnt == num_playlists) and (num_playlists > 0):
                    break

            playlist_cols = ['pid','name','num_albums','num_artists','num_edits','num_tracks','collaborative','duration_ms','modified_at']
            playlists_df = pd.DataFrame(playlists, columns=playlist_cols)
            #print(playlists_df.head())
            write_log('Adding all playlists to database from file: ' + filename)
            playlists_df.to_sql(name='playlists', con=conn, if_exists='append', index=False)

            rating_cols = ['pid', 'track_id', 'pos', 'num_followers']
            ratings_df = pd.DataFrame(ratings, columns=rating_cols)
            #print(ratings_df.head())
            write_log('Adding all ratings to database from file: ' + filename)
            ratings_df.to_sql(name='ratings', con=conn, if_exists='append', index=False)

            track_cols = ['track_id', 'track_name', 'track_uri', 'album_name', 'album_uri', 'artist_name', 'artist_uri']
            tracks_df = pd.DataFrame(tracks, columns=track_cols)
            #print(tracks_df.tail())
            write_log('Adding all tracks to database from file: ' + filename)
            tracks_df.to_sql(name='tracks', con=conn, if_exists='append', index=False)

    if conn:
        conn.close()

# %%
import plotly.express as px
from plotly.subplots import make_subplots

with open('../data/read_spotify_mpd_complete_log.txt') as log_file:
   playlist_files = []
   total_tracks = []
   exist_tracks = []
   new_tracks = []
   for line in log_file:
      line = line.strip()
      if 'Created new track_ids' in line:
         new_tracks.append(int(line.split(':')[1].rstrip()))
      if 'Tracks already exist' in line:
         exist_tracks.append(int(line.split(':')[1].rstrip()))
      if 'Total tracks/ratings in this file' in line:
         total_tracks.append(int(line.split(':')[1].rstrip()))
      if 'File: data/mpd.slice' in line:
         playlist_files.append(line.split('.')[-2])

   rows = 300
   exist_tracks_df = pd.DataFrame(zip(playlist_files, exist_tracks), columns=['files', 'num of tracks'])
   exist_tracks_df['tracks'] = 'existing'
   new_tracks_df = pd.DataFrame(zip(playlist_files, new_tracks), columns=['files', 'num of tracks'])
   new_tracks_df['tracks'] = 'new'
   total_tracks_df = pd.DataFrame(zip(playlist_files, total_tracks), columns=['files', 'num of tracks'])
   total_tracks_df['tracks'] = 'total'
   tracks_df = pd.concat([exist_tracks_df.iloc[:rows], total_tracks_df.iloc[:rows], new_tracks_df.iloc[:rows]])
   
   #subfig = make_subplots(rows=2, cols=1, specs=[[{"type": "xy"}], [{"type": "xy"}]])
   #subfig.add_bar(row=1, col=1, y=tracks_df['num of tracks'], x=tracks_df['files'])
   #subfig.add_bar(row=2, col=1, y=new_tracks_df['num of tracks'], x=new_tracks_df['files'])
   fig = px.bar(tracks_df[tracks_df['tracks'] != 'existing'],
             x='files',
             y='num of tracks',
             color='tracks',
             barmode='overlay')
   fig.show()
   
   fig = px.bar(tracks_df[tracks_df['tracks'] != 'total'],
             x='files',
             y='num of tracks',
             color='tracks',
             barmode='stack')
   fig.show()

# %%
sp = spotipy.Spotify(client_credentials_manager = SpotifyClientCredentials())
#json_data = sp.playlist('37i9dQZF1DX9tzt7g58Xlh')
json_data = sp.playlist_items('37i9dQZF1DX9tzt7g58Xlh', offset=0, fields='items.track.artists,items.track.id,items.track.name,items.track.album.id,items.track.album.name,total', additional_types=['track'])
import pprint
print(json_data['total'], len(json_data['items']))
pprint.pprint(json_data['items'])
# Out:
# 60 60
# [{'track': {'album': {'id': '1bTgKomQYSkKYPD9UI9W4b',
#                       'name': 'Enemy (with JID) [from the series Arcane League '
#                               'of Legends]'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/6U3ybJ9UHNKEdsH7ktGBZ7'},
#                          'href': 'https://api.spotify.com/v1/artists/6U3ybJ9UHNKEdsH7ktGBZ7',
#                          'id': '6U3ybJ9UHNKEdsH7ktGBZ7',
#                          'name': 'JID',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/57nPqD7z62gDdq37US9XJR'},
#                          'href': 'https://api.spotify.com/v1/artists/57nPqD7z62gDdq37US9XJR',
#                          'id': '57nPqD7z62gDdq37US9XJR',
#                          'name': 'Arcane',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:57nPqD7z62gDdq37US9XJR'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/47mIJdHORyRerp4os813jD'},
#                          'href': 'https://api.spotify.com/v1/artists/47mIJdHORyRerp4os813jD',
#                          'id': '47mIJdHORyRerp4os813jD',
#                          'name': 'League of Legends',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:47mIJdHORyRerp4os813jD'}],
#             'id': '1r9xUipOqoNwggBpENDsvJ',
#             'name': 'Enemy (with JID) - from the series Arcane League of '
#                     'Legends'}},
#  {'track': {'album': {'id': '6gblom0Rg1ZWvhMI1w2RUU',
#                       'name': 'Night Visions (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#                          'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#                          'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#                          'name': 'Kendrick Lamar',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#             'id': '6nDAs3PRe37fgqLfx51lBB',
#             'name': 'Radioactive'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '0CcQNd8CINkwQfe1RDtGV6',
#             'name': 'Believer'}},
#  {'track': {'album': {'id': '1vAEF8F0HoRFGiYOEeJXHW',
#                       'name': 'Night Visions (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '2Oehrcv4Kov0SuIgWyQY9e',
#             'name': 'Demons'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '149BxWeweaCqmsyedkNiiE',
#             'name': 'Wrecked'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '0tKcYR2II1VCQWT79i5NrW',
#             'name': 'Thunder'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '2FY7b99s15jUprqC0M5NCT',
#             'name': 'Natural'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6tvDAC8atHIjyLgvOEK1fK',
#             'name': 'Monday'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4IWAyPf1KMq7JCyGeCjTeH',
#             'name': 'Whatever It Takes'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '2RSHsoi04658QL5xgQVov3',
#             'name': 'Bad Liar'}},
#  {'track': {'album': {'id': '0OXJFBFvYP5b2U0qWUQehJ', 'name': 'Birds'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ARH58Hit3yC6ziGdhma23'},
#                          'href': 'https://api.spotify.com/v1/artists/2ARH58Hit3yC6ziGdhma23',
#                          'id': '2ARH58Hit3yC6ziGdhma23',
#                          'name': 'Elisa',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:2ARH58Hit3yC6ziGdhma23'}],
#             'id': '2uZVfvOK7MTjBTRICYmpso',
#             'name': 'Birds (feat. Elisa)'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '5QLhl7uDuDypn7kN34RFPj',
#             'name': 'Dull Knives'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6xSIsFET1hxpaYFQuHux4P',
#             'name': 'My Life'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '3mk4p8cBDd9bzTgooRrFoG',
#             'name': 'Lonely'}},
#  {'track': {'album': {'id': '1vAEF8F0HoRFGiYOEeJXHW',
#                       'name': 'Night Visions (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '3xqF04FdMK7gpIPG3SPFpY',
#             'name': "It's Time"}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6z39NC4VSSweBHFg9kAoja',
#             'name': '#1'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '375kzpRydDdOxOSCGMK53b',
#             'name': 'Follow You'}},
#  {'track': {'album': {'id': '2t4SjuB6sBEozekaNrFrQQ',
#                       'name': 'Smoke + Mirrors'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '0mZriPjLPG9PExNzKQ3NVS',
#             'name': 'Warriors'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '3wWXNV94Ys2vQcFxgnWkut',
#             'name': 'Easy Come Easy Go'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '7FNq9WjxUTIx6OCSPzzopE',
#             'name': 'Giants'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '1BhkCNB6yE8OPdOnazI3O5',
#             'name': "It's Ok"}},
#  {'track': {'album': {'id': '58401eNNELkIVx3xiwzJFy',
#                       'name': 'Bad Liar – Stripped'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6hFi0gXP8KItwMqfBgf44b',
#             'name': 'Bad Liar – Stripped'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4XhseSDGzoj15T6sWy97L9',
#             'name': 'Cutthroat'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '7MzYWwzeBKEQ2rRGUQmdES',
#             'name': 'One Day'}},
#  {'track': {'album': {'id': '6DdU5f52hpc2gfeLjK374Y',
#                       'name': 'Mercury - Act 1'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '591rVlNAjjUyA44aq6PzTH',
#             'name': 'No Time For Toxic People'}},
#  {'track': {'album': {'id': '6Q0aPCxLqK5EDSJdlPkNeT',
#                       'name': 'Believer (feat. Lil Wayne)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#                          'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#                          'id': '55Aa2cqylxrFIXC767Z865',
#                          'name': 'Lil Wayne',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'}],
#             'id': '2sU9EjevkrU9OkPZudvFNN',
#             'name': 'Believer (feat. Lil Wayne)'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '2bzitsPcImYC6DZWvvLCQi',
#             'name': 'Zero - From the Original Motion Picture "Ralph Breaks The '
#                     'Internet"'}},
#  {'track': {'album': {'id': '1vAEF8F0HoRFGiYOEeJXHW',
#                       'name': 'Night Visions (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4eLSCSELtKxZwXnFbNLXT5',
#             'name': 'On Top Of The World'}},
#  {'track': {'album': {'id': '57lkUmA6WunanwJRN1RsGD', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '7EUfNvyCVxQV3oN5ScA2Lb',
#             'name': 'Next To Me'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6jmngk8Fwup05JZ6kgXEGX',
#             'name': 'Walking The Wire'}},
#  {'track': {'album': {'id': '2XjPrtaAqvviEgSHCpzHmM',
#                       'name': 'Smoke + Mirrors (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/3836OTICMPjhTMMcpPw4EC'},
#                          'href': 'https://api.spotify.com/v1/artists/3836OTICMPjhTMMcpPw4EC',
#                          'id': '3836OTICMPjhTMMcpPw4EC',
#                          'name': 'Broiler',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:3836OTICMPjhTMMcpPw4EC'}],
#             'id': '0z8yrlXSjnI29Rv30RssNI',
#             'name': 'Shots - Broiler Remix'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '1uRBbjQ3uNFXCncWyNomHf',
#             'name': 'Only'}},
#  {'track': {'album': {'id': '3wWirod6bwh5AwxWYuKQVa',
#                       'name': 'Thunder / Young Dumb & Broke (with Khalid) '
#                               '[Medley]'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#                          'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#                          'id': '6LuN9FCkKOj5PcnpouEgny',
#                          'name': 'Khalid',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#             'id': '05W4TSNqPEXtKdejLVRQrm',
#             'name': 'Thunder / Young Dumb & Broke (with Khalid) - Medley'}},
#  {'track': {'album': {'id': '5a7xlzy9LsS4EwKeOIojMX',
#                       'name': 'Smoke + Mirrors (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4eavkrdMt3ypQcnVmzGP5L',
#             'name': 'Monster'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '7vAXN57IQ0sj049wZGIboE',
#             'name': 'Rise Up'}},
#  {'track': {'album': {'id': '0gmsXcmrcnxdZBrD5EyJEL',
#                       'name': 'Smoke + Mirrors'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '15DrrIod12Tc2IoMaHiwlQ',
#             'name': 'I Bet My Life'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6Tvzf3VEi16JMhAgOwdt2y',
#             'name': 'Birds'}},
#  {'track': {'album': {'id': '0gmsXcmrcnxdZBrD5EyJEL',
#                       'name': 'Smoke + Mirrors'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '25DpvTS4zsmLiVLx8Zv3N0',
#             'name': 'Dream'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '5d41vXH0zvpwUrHrmqKqDc',
#             'name': 'Love'}},
#  {'track': {'album': {'id': '6rKQIcPyDLYnXzcINhnLYA',
#                       'name': 'Smoke + Mirrors (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '2AObzKd3JYIWQqQ067Z0YI',
#             'name': 'Release'}},
#  {'track': {'album': {'id': '1vAEF8F0HoRFGiYOEeJXHW',
#                       'name': 'Night Visions (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '0RchWnEHETINMAyrTrlBmo',
#             'name': 'Bleeding Out'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '5Z9SQPYU95S6M1vcbLsDt2',
#             'name': 'Stuck'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '7JAzAyjbJFPznEFdqpa1Si',
#             'name': 'Real Life'}},
#  {'track': {'album': {'id': '5a7xlzy9LsS4EwKeOIojMX',
#                       'name': 'Smoke + Mirrors (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '236DIFE6J4lbdknreVZSN6',
#             'name': 'Who We Are'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '5Q7zuH8VNu7aLappSusPu6',
#             'name': 'Burn Out'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6dSKDp21S6I5UOhDqjw4kB',
#             'name': 'Mouth Of The River'}},
#  {'track': {'album': {'id': '6SW9d1zYefC5SUzPsJFUMU', 'name': 'Roots'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4GITtbZtRCQXhWLMXrWXHt',
#             'name': 'Roots'}},
#  {'track': {'album': {'id': '0gmsXcmrcnxdZBrD5EyJEL',
#                       'name': 'Smoke + Mirrors'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4o74y4XY1ypNZkZtZkK8Wi',
#             'name': 'I’m So Sorry'}},
#  {'track': {'album': {'id': '31J0UqxAkl9utyC0L59Mae',
#                       'name': 'Born To Be Yours'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#                          'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#                          'id': '23fqKkggKUBHNkbKtXEls4',
#                          'name': 'Kygo',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '0kHyKhJMukHEPfeh8s7rdM',
#             'name': 'Born To Be Yours'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '15dnkAHcHC0vrIUlbiPiqU',
#             'name': 'I Don’t Know Why'}},
#  {'track': {'album': {'id': '68pBVLvF14n0d3c6BYlOTk',
#                       'name': 'Me Before You (Original Motion Picture '
#                               'Soundtrack)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '3Y6ILqXqCBNwBTxVda8Z68',
#             'name': 'Not Today'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '2nkoWsTZa8LKPNGdjI5uxj',
#             'name': 'West Coast'}},
#  {'track': {'album': {'id': '5a7xlzy9LsS4EwKeOIojMX',
#                       'name': 'Smoke + Mirrors (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '1HW6A7IaPggPryCLsTUj5c',
#             'name': 'Battle Cry'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '4uGY9CqDtGtaTTLg1cgsWD',
#             'name': 'Machine'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '54h8xHewdRPnYzmbEHBhOO',
#             'name': 'I’ll Make It Up To You'}},
#  {'track': {'album': {'id': '5GlPAy2PRJW06GVFhKwGTl', 'name': 'Evolve'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '5HvtbJxOYLSACcPuhf62wT',
#             'name': 'Dancing In The Dark'}},
#  {'track': {'album': {'id': '3JfSxDfmwS5OeHPwLSkrfr',
#                       'name': 'Origins (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '3R4Xk37WTagjzODMNEQLvs',
#             'name': 'Bullet In A Gun'}},
#  {'track': {'album': {'id': '0gmsXcmrcnxdZBrD5EyJEL',
#                       'name': 'Smoke + Mirrors'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '1WQFOwtI6EfsvRz7wcDbQm',
#             'name': 'Gold'}},
#  {'track': {'album': {'id': '1vAEF8F0HoRFGiYOEeJXHW',
#                       'name': 'Night Visions (Deluxe)'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '6YUFByainM0IB52DNObY5t',
#             'name': 'Tiptoe'}},
#  {'track': {'album': {'id': '6htgf3qv7vGcsdxLCDxKp8', 'name': 'Night Visions'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#                          'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#                          'id': '53XhwfbYqKCa1cC15pYq2q',
#                          'name': 'Imagine Dragons',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#             'id': '1OppUXF0ZsVATRbEyHOTyA',
#             'name': 'Cha-Ching (Till We Grow Older)'}}]

# %%
tracks = pd.json_normalize(json_data['tracks']['items'], record_path=['track', 'artists'], meta=[['track', 'name'], ['track', 'id'], ['track', 'album', 'name'], ['track', 'album', 'id']])
print(tracks.head())
tracks.columns
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6Dd3NScHWwn...  6Dd3NScHWwnW6obMFbl1BH
# 1  https://api.spotify.com/v1/artists/1pRaG81GsVt...  1pRaG81GsVtaTBuVSpldt2
# 2  https://api.spotify.com/v1/artists/3HVdAiMNjYr...  3HVdAiMNjYrQIKlOGxoGh5
# 3  https://api.spotify.com/v1/artists/1ZilzPhvZhY...  1ZilzPhvZhYUCSGczNRlyt
# 4  https://api.spotify.com/v1/artists/2VYQTNDsvvK...  2VYQTNDsvvKN9wmU5W7xpj
#
#              name    type                                    uri  \
# 0            Daya  artist  spotify:artist:6Dd3NScHWwnW6obMFbl1BH
# 1        Pop Evil  artist  spotify:artist:1pRaG81GsVtaTBuVSpldt2
# 2      Rob Zombie  artist  spotify:artist:3HVdAiMNjYrQIKlOGxoGh5
# 3      Eli Sostre  artist  spotify:artist:1ZilzPhvZhYUCSGczNRlyt
# 4  Marilyn Manson  artist  spotify:artist:2VYQTNDsvvKN9wmU5W7xpj
#
#                                external_urls.spotify              track.name  \
# 0  https://open.spotify.com/artist/6Dd3NScHWwnW6o...  Sit Still, Look Pretty
# 1  https://open.spotify.com/artist/1pRaG81GsVtaTB...     Deal with the Devil
# 2  https://open.spotify.com/artist/3HVdAiMNjYrQIK...        Living Dead Girl
# 3  https://open.spotify.com/artist/1ZilzPhvZhYUCS...              Let You Go
# 4  https://open.spotify.com/artist/2VYQTNDsvvKN9w...         ハロウィーン・タウンへようこそ
#
#                  track.id        track.album.name          track.album.id
# 0  2DpCdPMg1BADE4HDnxt3Rd  Sit Still, Look Pretty  2cE2eOy7alOZHpuelJEV8Q
# 1  6LEpnhwG1zFp7rmSgzt9qr                    Onyx  5tu3lWy5noRh9hGYq8obgk
# 2  10V8XpuyMoEcSMfM79WDET        Hellbilly Deluxe  2B4lHoTCpWbxQPTZmCOjnH
# 3  5XYgc2ZMwf5prTOMtfVnpW   Sleep Is for the Weak  5i9HTp05n9RO828DjJmjJt
# 4  6HY9uBtiScVdnsp18WbqHT          ナイトメアー・リヴィジテッド  6UGnl3MpXzNYaI7KNjQTxe
# Index(['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify',
#        'track.name', 'track.id', 'track.album.name', 'track.album.id'],
#       dtype='object')

# %%
tracks = pd.json_normalize(json_data['items'])
print(len(tracks))
tracks.head()
# Out:
# 60
#            track.album.id                                   track.album.name  \
# 0  1bTgKomQYSkKYPD9UI9W4b  Enemy (with JID) [from the series Arcane Leagu...
# 1  6gblom0Rg1ZWvhMI1w2RUU                             Night Visions (Deluxe)
# 2  5GlPAy2PRJW06GVFhKwGTl                                             Evolve
# 3  1vAEF8F0HoRFGiYOEeJXHW                             Night Visions (Deluxe)
# 4  6DdU5f52hpc2gfeLjK374Y                                    Mercury - Act 1
#
#                                        track.artists                track.id  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  1r9xUipOqoNwggBpENDsvJ
# 1  [{'external_urls': {'spotify': 'https://open.s...  6nDAs3PRe37fgqLfx51lBB
# 2  [{'external_urls': {'spotify': 'https://open.s...  0CcQNd8CINkwQfe1RDtGV6
# 3  [{'external_urls': {'spotify': 'https://open.s...  2Oehrcv4Kov0SuIgWyQY9e
# 4  [{'external_urls': {'spotify': 'https://open.s...  149BxWeweaCqmsyedkNiiE
#
#                                           track.name
# 0  Enemy (with JID) - from the series Arcane Leag...
# 1                                        Radioactive
# 2                                           Believer
# 3                                             Demons
# 4                                            Wrecked

# %%
scope = "user-library-read"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))
tracks = sp.current_user_saved_tracks()

# %%
tracks['items']
# Out:
# [{'added_at': '2021-09-05T22:32:25Z',
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LC',
#      'LI',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ecx4OFG0nlUMqAi9OXQER'},
#     'href': 'https://api.spotify.com/v1/albums/6ecx4OFG0nlUMqAi9OXQER',
#     'id': '6ecx4OFG0nlUMqAi9OXQER',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731551c93dfa33ea4f30ef4eea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511551c93dfa33ea4f30ef4eea',
#       'width': 64}],
#     'name': 'Smoke + Mirrors (Deluxe)',
#     'release_date': '2015-10-30',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:6ecx4OFG0nlUMqAi9OXQER'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#      'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#      'id': '53XhwfbYqKCa1cC15pYq2q',
#      'name': 'Imagine Dragons',
#      'type': 'artist',
#      'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LC',
#     'LI',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 170066,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71414163'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1lgN0A2Vki2FTON5PYq42m'},
#    'href': 'https://api.spotify.com/v1/tracks/1lgN0A2Vki2FTON5PYq42m',
#    'id': '1lgN0A2Vki2FTON5PYq42m',
#    'is_local': False,
#    'name': 'Warriors',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e826a4abd230128dcb403c677c3319279f70fa18?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:1lgN0A2Vki2FTON5PYq42m'}},
#  {'added_at': '2021-08-27T20:55:52Z',
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MxrLrq7vFme5jY2PPwmsO'},
#       'href': 'https://api.spotify.com/v1/artists/0MxrLrq7vFme5jY2PPwmsO',
#       'id': '0MxrLrq7vFme5jY2PPwmsO',
#       'name': 'Harrish Jayaraj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0MxrLrq7vFme5jY2PPwmsO'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4WfRVG2X8hJPRINDJ3DWG3'},
#     'href': 'https://api.spotify.com/v1/albums/4WfRVG2X8hJPRINDJ3DWG3',
#     'id': '4WfRVG2X8hJPRINDJ3DWG3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734e67e1eb1b50604990c86ba4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024e67e1eb1b50604990c86ba4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514e67e1eb1b50604990c86ba4',
#       'width': 64}],
#     'name': 'Orange',
#     'release_date': '2010-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:4WfRVG2X8hJPRINDJ3DWG3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qrS6jqZfr8HJe3IWkQqv2'},
#      'href': 'https://api.spotify.com/v1/artists/6qrS6jqZfr8HJe3IWkQqv2',
#      'id': '6qrS6jqZfr8HJe3IWkQqv2',
#      'name': 'Karunya',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qrS6jqZfr8HJe3IWkQqv2'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wr6cv6sLD88vQKkMy8w2H'},
#      'href': 'https://api.spotify.com/v1/artists/5wr6cv6sLD88vQKkMy8w2H',
#      'id': '5wr6cv6sLD88vQKkMy8w2H',
#      'name': 'Ranina Reddy',
#      'type': 'artist',
#      'uri': 'spotify:artist:5wr6cv6sLD88vQKkMy8w2H'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 334688,
#    'explicit': False,
#    'external_ids': {'isrc': 'INA091012541'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/59j1ZUoWtcJqiEycTmOl0d'},
#    'href': 'https://api.spotify.com/v1/tracks/59j1ZUoWtcJqiEycTmOl0d',
#    'id': '59j1ZUoWtcJqiEycTmOl0d',
#    'is_local': False,
#    'name': 'Ola Olaala Ala',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:59j1ZUoWtcJqiEycTmOl0d'}},
#  {'added_at': '2021-08-20T00:51:53Z',
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/30rejoGJuhKKQZJ1cT25T0'},
#     'href': 'https://api.spotify.com/v1/albums/30rejoGJuhKKQZJ1cT25T0',
#     'id': '30rejoGJuhKKQZJ1cT25T0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739634d8de3eca5f38dcc211a3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029634d8de3eca5f38dcc211a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519634d8de3eca5f38dcc211a3',
#       'width': 64}],
#     'name': 'Maharshi',
#     'release_date': '2019-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:30rejoGJuhKKQZJ1cT25T0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LSPREIgGMZXCuKVel7LVD'},
#      'href': 'https://api.spotify.com/v1/artists/0LSPREIgGMZXCuKVel7LVD',
#      'id': '0LSPREIgGMZXCuKVel7LVD',
#      'name': 'Karthik',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LSPREIgGMZXCuKVel7LVD'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 260700,
#    'explicit': False,
#    'external_ids': {'isrc': 'INA091816481'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2OTWTkshnDUT3pKrf0ElOh'},
#    'href': 'https://api.spotify.com/v1/tracks/2OTWTkshnDUT3pKrf0ElOh',
#    'id': '2OTWTkshnDUT3pKrf0ElOh',
#    'is_local': False,
#    'name': 'Nuvvani Idhi Needani',
#    'popularity': 34,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4049b9faab4cc992b08a60dfb9dfb814d2cab887?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:2OTWTkshnDUT3pKrf0ElOh'}},
#  {'added_at': '2021-07-27T01:09:07Z',
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09UmIX92EUH9hAK4bxvHx6'},
#       'href': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6',
#       'id': '09UmIX92EUH9hAK4bxvHx6',
#       'name': 'Mithoon',
#       'type': 'artist',
#       'uri': 'spotify:artist:09UmIX92EUH9hAK4bxvHx6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/74OaRjmyh0XyRZsQQQ5l7c'},
#       'href': 'https://api.spotify.com/v1/artists/74OaRjmyh0XyRZsQQQ5l7c',
#       'id': '74OaRjmyh0XyRZsQQQ5l7c',
#       'name': 'Jasleen Royal',
#       'type': 'artist',
#       'uri': 'spotify:artist:74OaRjmyh0XyRZsQQQ5l7c'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0gCcyIYaX8OK2BcKs8behf'},
#     'href': 'https://api.spotify.com/v1/albums/0gCcyIYaX8OK2BcKs8behf',
#     'id': '0gCcyIYaX8OK2BcKs8behf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e7fe7d656750737e8d369f95',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e7fe7d656750737e8d369f95',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e7fe7d656750737e8d369f95',
#       'width': 64}],
#     'name': 'Shivaay',
#     'release_date': '2016-10-07',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:0gCcyIYaX8OK2BcKs8behf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09UmIX92EUH9hAK4bxvHx6'},
#      'href': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6',
#      'id': '09UmIX92EUH9hAK4bxvHx6',
#      'name': 'Mithoon',
#      'type': 'artist',
#      'uri': 'spotify:artist:09UmIX92EUH9hAK4bxvHx6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5GnnSrwNCGyfAU4zuIytiS'},
#      'href': 'https://api.spotify.com/v1/artists/5GnnSrwNCGyfAU4zuIytiS',
#      'id': '5GnnSrwNCGyfAU4zuIytiS',
#      'name': 'Mohit Chauhan',
#      'type': 'artist',
#      'uri': 'spotify:artist:5GnnSrwNCGyfAU4zuIytiS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/19MVxKZZdPj2X0F8pi0OCT'},
#      'href': 'https://api.spotify.com/v1/artists/19MVxKZZdPj2X0F8pi0OCT',
#      'id': '19MVxKZZdPj2X0F8pi0OCT',
#      'name': 'Sukhwinder Singh',
#      'type': 'artist',
#      'uri': 'spotify:artist:19MVxKZZdPj2X0F8pi0OCT'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0y59o4v8uw5crbN9M3JiL1'},
#      'href': 'https://api.spotify.com/v1/artists/0y59o4v8uw5crbN9M3JiL1',
#      'id': '0y59o4v8uw5crbN9M3JiL1',
#      'name': 'Badshah',
#      'type': 'artist',
#      'uri': 'spotify:artist:0y59o4v8uw5crbN9M3JiL1'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2KhDedackjZfysiu7T7AwN'},
#      'href': 'https://api.spotify.com/v1/artists/2KhDedackjZfysiu7T7AwN',
#      'id': '2KhDedackjZfysiu7T7AwN',
#      'name': 'Megha Sriram Dalton',
#      'type': 'artist',
#      'uri': 'spotify:artist:2KhDedackjZfysiu7T7AwN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZCPRtzF2CRFnP9OYHQGmN'},
#      'href': 'https://api.spotify.com/v1/artists/1ZCPRtzF2CRFnP9OYHQGmN',
#      'id': '1ZCPRtzF2CRFnP9OYHQGmN',
#      'name': 'Anugrah',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZCPRtzF2CRFnP9OYHQGmN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7qATomOqJzoJiuEpAaxOXd'},
#      'href': 'https://api.spotify.com/v1/artists/7qATomOqJzoJiuEpAaxOXd',
#      'id': '7qATomOqJzoJiuEpAaxOXd',
#      'name': 'Sandeep Shrivastava',
#      'type': 'artist',
#      'uri': 'spotify:artist:7qATomOqJzoJiuEpAaxOXd'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 294331,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS181601543'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7rMqbvNImA6wy8lxlNUMmj'},
#    'href': 'https://api.spotify.com/v1/tracks/7rMqbvNImA6wy8lxlNUMmj',
#    'id': '7rMqbvNImA6wy8lxlNUMmj',
#    'is_local': False,
#    'name': 'Bolo Har Har Har (feat. Mohit Chauhan, Sukhwinder Singh, Badshah, Megha Sriram Dalton, Anugrah, Sandeep Shrivastava)',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bfeaeb53b793b0d8f3957acd7fc0d0dfcd039ef2?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7rMqbvNImA6wy8lxlNUMmj'}},
#  {'added_at': '2021-05-20T23:21:11Z',
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7HCqGPJcQTyGJ2yqntbuyr'},
#       'href': 'https://api.spotify.com/v1/artists/7HCqGPJcQTyGJ2yqntbuyr',
#       'id': '7HCqGPJcQTyGJ2yqntbuyr',
#       'name': 'Amit Trivedi',
#       'type': 'artist',
#       'uri': 'spotify:artist:7HCqGPJcQTyGJ2yqntbuyr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3mOFY0HwnLOGsnpeH5WTdd'},
#     'href': 'https://api.spotify.com/v1/albums/3mOFY0HwnLOGsnpeH5WTdd',
#     'id': '3mOFY0HwnLOGsnpeH5WTdd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739ab723e0fc5c86b514d31477',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029ab723e0fc5c86b514d31477',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519ab723e0fc5c86b514d31477',
#       'width': 64}],
#     'name': 'V',
#     'release_date': '2020-03-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3mOFY0HwnLOGsnpeH5WTdd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oOet2f43PA68X5RxKobEy'},
#      'href': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy',
#      'id': '0oOet2f43PA68X5RxKobEy',
#      'name': 'Shreya Ghoshal',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oOet2f43PA68X5RxKobEy'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7HCqGPJcQTyGJ2yqntbuyr'},
#      'href': 'https://api.spotify.com/v1/artists/7HCqGPJcQTyGJ2yqntbuyr',
#      'id': '7HCqGPJcQTyGJ2yqntbuyr',
#      'name': 'Amit Trivedi',
#      'type': 'artist',
#      'uri': 'spotify:artist:7HCqGPJcQTyGJ2yqntbuyr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LWyVEIBnx7MoRBhQxu9om'},
#      'href': 'https://api.spotify.com/v1/artists/6LWyVEIBnx7MoRBhQxu9om',
#      'id': '6LWyVEIBnx7MoRBhQxu9om',
#      'name': 'Anurag Kulkarni',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LWyVEIBnx7MoRBhQxu9om'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 212000,
#    'explicit': False,
#    'external_ids': {'isrc': 'INA092016835'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0VMigv7BI8OpP6CRSkyKX6'},
#    'href': 'https://api.spotify.com/v1/tracks/0VMigv7BI8OpP6CRSkyKX6',
#    'id': '0VMigv7BI8OpP6CRSkyKX6',
#    'is_local': False,
#    'name': 'Vastunna Vachestunna - Telugu',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0607eac18b948e8e4e816669144d2794033fa194?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0VMigv7BI8OpP6CRSkyKX6'}},
#  {'added_at': '2021-05-19T00:13:09Z',
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0algcmWDo4iWiZYoRt540l'},
#     'href': 'https://api.spotify.com/v1/albums/0algcmWDo4iWiZYoRt540l',
#     'id': '0algcmWDo4iWiZYoRt540l',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b03d357fbd7316487be9bf00',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b03d357fbd7316487be9bf00',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b03d357fbd7316487be9bf00',
#       'width': 64}],
#     'name': 'Nenu Local (Original Motion Picture Soundtrack)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:0algcmWDo4iWiZYoRt540l'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qRMj0A3Z6fcxQMZVaXhp0'},
#      'href': 'https://api.spotify.com/v1/artists/1qRMj0A3Z6fcxQMZVaXhp0',
#      'id': '1qRMj0A3Z6fcxQMZVaXhp0',
#      'name': 'Kapil',
#      'type': 'artist',
#      'uri': 'spotify:artist:1qRMj0A3Z6fcxQMZVaXhp0'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/10CItw8tdXThklMWPI55vu'},
#      'href': 'https://api.spotify.com/v1/artists/10CItw8tdXThklMWPI55vu',
#      'id': '10CItw8tdXThklMWPI55vu',
#      'name': 'Sameera Bharadwaj',
#      'type': 'artist',
#      'uri': 'spotify:artist:10CItw8tdXThklMWPI55vu'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 200506,
#    'explicit': False,
#    'external_ids': {'isrc': 'INA091715357'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0qWNEKbyc4fdMUQYSYSkVQ'},
#    'href': 'https://api.spotify.com/v1/tracks/0qWNEKbyc4fdMUQYSYSkVQ',
#    'id': '0qWNEKbyc4fdMUQYSYSkVQ',
#    'is_local': False,
#    'name': 'Champesaave Nannu',
#    'popularity': 0,
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:0qWNEKbyc4fdMUQYSYSkVQ'}},
#  {'added_at': '2021-04-15T22:19:18Z',
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/78qmjdCxeGrzTTPSlvieS7'},
#       'href': 'https://api.spotify.com/v1/artists/78qmjdCxeGrzTTPSlvieS7',
#       'id': '78qmjdCxeGrzTTPSlvieS7',
#       'name': 'Priya Sisters',
#       'type': 'artist',
#       'uri': 'spotify:artist:78qmjdCxeGrzTTPSlvieS7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4chaNgEIyPTljtUofAEvwf'},
#     'href': 'https://api.spotify.com/v1/albums/4chaNgEIyPTljtUofAEvwf',
#     'id': '4chaNgEIyPTljtUofAEvwf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27318768c13496d7642f1ab2531',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0218768c13496d7642f1ab2531',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485118768c13496d7642f1ab2531',
#       'width': 64}],
#     'name': 'Lalitha Pancharatnam',
#     'release_date': '1993',
#     'release_date_precision': 'year',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:4chaNgEIyPTljtUofAEvwf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/78qmjdCxeGrzTTPSlvieS7'},
#      'href': 'https://api.spotify.com/v1/artists/78qmjdCxeGrzTTPSlvieS7',
#      'id': '78qmjdCxeGrzTTPSlvieS7',
#      'name': 'Priya Sisters',
#      'type': 'artist',
#      'uri': 'spotify:artist:78qmjdCxeGrzTTPSlvieS7'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 1755311,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR10S1422915'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0syWP6hExPrVVfq8yVL0oa'},
#    'href': 'https://api.spotify.com/v1/tracks/0syWP6hExPrVVfq8yVL0oa',
#    'id': '0syWP6hExPrVVfq8yVL0oa',
#    'is_local': False,
#    'name': 'Lalitha Sahasranama Sthothram',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0f9f02a15c31ac98d691f92fa926c50a115c9f77?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0syWP6hExPrVVfq8yVL0oa'}},
#  {'added_at': '2021-02-03T21:30:04Z',
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7hsmqtpwTo6W2jGsTdJi'},
#       'href': 'https://api.spotify.com/v1/artists/3e7hsmqtpwTo6W2jGsTdJi',
#       'id': '3e7hsmqtpwTo6W2jGsTdJi',
#       'name': 'Mike Slam',
#       'type': 'artist',
#       'uri': 'spotify:artist:3e7hsmqtpwTo6W2jGsTdJi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/13UN3LbfjYD81kj21pdhlJ'},
#     'href': 'https://api.spotify.com/v1/albums/13UN3LbfjYD81kj21pdhlJ',
#     'id': '13UN3LbfjYD81kj21pdhlJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d7164441838c028b05c04012',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d7164441838c028b05c04012',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d7164441838c028b05c04012',
#       'width': 64}],
#     'name': 'Gone Girl (Scented Aromas)',
#     'release_date': '2021-02-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:13UN3LbfjYD81kj21pdhlJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7hsmqtpwTo6W2jGsTdJi'},
#      'href': 'https://api.spotify.com/v1/artists/3e7hsmqtpwTo6W2jGsTdJi',
#      'id': '3e7hsmqtpwTo6W2jGsTdJi',
#      'name': 'Mike Slam',
#      'type': 'artist',
#      'uri': 'spotify:artist:3e7hsmqtpwTo6W2jGsTdJi'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 143551,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZFZ42155259'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7477u0VcaCbszkgc915VZL'},
#    'href': 'https://api.spotify.com/v1/tracks/7477u0VcaCbszkgc915VZL',
#    'id': '7477u0VcaCbszkgc915VZL',
#    'is_local': False,
#    'name': 'Gone Girl (Scented Aromas)',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/285c33a79c81df94e58c2fa67b30998e136acb4f?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7477u0VcaCbszkgc915VZL'}},
#  {'added_at': '2020-12-30T17:40:07Z',
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DX2CLnA9ajgQuNf5jqEXl'},
#       'href': 'https://api.spotify.com/v1/artists/7DX2CLnA9ajgQuNf5jqEXl',
#       'id': '7DX2CLnA9ajgQuNf5jqEXl',
#       'name': 'Nihal',
#       'type': 'artist',
#       'uri': 'spotify:artist:7DX2CLnA9ajgQuNf5jqEXl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ReRGS15ayrHbEOgL32CeM'},
#     'href': 'https://api.spotify.com/v1/albums/0ReRGS15ayrHbEOgL32CeM',
#     'id': '0ReRGS15ayrHbEOgL32CeM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b8b4d82168e6e816e370b3ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b8b4d82168e6e816e370b3ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b8b4d82168e6e816e370b3ca',
#       'width': 64}],
#     'name': 'Shivoham',
#     'release_date': '2002-05-25',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:0ReRGS15ayrHbEOgL32CeM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ae6PxICSOZHvjqiCcgon8'},
#      'href': 'https://api.spotify.com/v1/artists/2ae6PxICSOZHvjqiCcgon8',
#      'id': '2ae6PxICSOZHvjqiCcgon8',
#      'name': 'S. P. Balasubrahmanyam',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ae6PxICSOZHvjqiCcgon8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
# ...
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3wAsZ0sTfkJvspCMlW5azC'},
#     'href': 'https://api.spotify.com/v1/albums/3wAsZ0sTfkJvspCMlW5azC',
#     'id': '3wAsZ0sTfkJvspCMlW5azC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273422706845cccb27ac30953c8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02422706845cccb27ac30953c8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851422706845cccb27ac30953c8',
#       'width': 64}],
#     'name': 'Maharshi',
#     'release_date': '2019-05-04',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:3wAsZ0sTfkJvspCMlW5azC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#      'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#      'id': '5sSzCxHtgL82pYDvx2QyEU',
#      'name': 'Devi Sri Prasad',
#      'type': 'artist',
#      'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 265108,
#    'explicit': False,
#    'external_ids': {'isrc': 'INA091816438'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Eml6rgqnl2Vm4jHspmYoy'},
#    'href': 'https://api.spotify.com/v1/tracks/2Eml6rgqnl2Vm4jHspmYoy',
#    'id': '2Eml6rgqnl2Vm4jHspmYoy',
#    'is_local': False,
#    'name': 'Choti Choti Baatein',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/26d3b6d003939ec33a573b572c5a81ac2e83a9cd?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2Eml6rgqnl2Vm4jHspmYoy'}},
#  {'added_at': '2020-08-05T23:35:37Z',
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1pE2RYH3lcDdLpMVjBslBp'},
#     'href': 'https://api.spotify.com/v1/albums/1pE2RYH3lcDdLpMVjBslBp',
#     'id': '1pE2RYH3lcDdLpMVjBslBp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cc40809532d536f42d703256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cc40809532d536f42d703256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cc40809532d536f42d703256',
#       'width': 64}],
#     'name': 'Nenu Sailaja',
#     'release_date': '2015-12-21',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:1pE2RYH3lcDdLpMVjBslBp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LSPREIgGMZXCuKVel7LVD'},
#      'href': 'https://api.spotify.com/v1/artists/0LSPREIgGMZXCuKVel7LVD',
#      'id': '0LSPREIgGMZXCuKVel7LVD',
#      'name': 'Karthik',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LSPREIgGMZXCuKVel7LVD'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 286642,
#    'explicit': False,
#    'external_ids': {'isrc': 'INA091515016'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/40sRF4TRBsIBERczzU2JY2'},
#    'href': 'https://api.spotify.com/v1/tracks/40sRF4TRBsIBERczzU2JY2',
#    'id': '40sRF4TRBsIBERczzU2JY2',
#    'is_local': False,
#    'name': 'Em Cheppanu',
#    'popularity': 45,
#    'preview_url': 'https://p.scdn.co/mp3-preview/29cbb4fbadf606cb471d3f8d3ea823f746bd60b0?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:40sRF4TRBsIBERczzU2JY2'}},
#  {'added_at': '2020-08-05T23:31:23Z',
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU'},
#       'href': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU',
#       'id': '5sSzCxHtgL82pYDvx2QyEU',
#       'name': 'Devi Sri Prasad',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4WSLvIQ3Q6vhYQIxXi7mn8'},
#     'href': 'https://api.spotify.com/v1/albums/4WSLvIQ3Q6vhYQIxXi7mn8',
#     'id': '4WSLvIQ3Q6vhYQIxXi7mn8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dabca19fe6ea5d191c93cdd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dabca19fe6ea5d191c93cdd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dabca19fe6ea5d191c93cdd',
#       'width': 64}],
#     'name': 'Janatha Garage',
#     'release_date': '2016-08-12',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:4WSLvIQ3Q6vhYQIxXi7mn8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rdQOMFFtoskDXXUVjiGo9'},
#      'href': 'https://api.spotify.com/v1/artists/1rdQOMFFtoskDXXUVjiGo9',
#      'id': '1rdQOMFFtoskDXXUVjiGo9',
#      'name': 'Shweta Mohan',
#      'type': 'artist',
#      'uri': 'spotify:artist:1rdQOMFFtoskDXXUVjiGo9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 97680,
#    'explicit': False,
#    'external_ids': {'isrc': 'INS181601341'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/14ZvcewteMfdD32us40NDC'},
#    'href': 'https://api.spotify.com/v1/tracks/14ZvcewteMfdD32us40NDC',
#    'id': '14ZvcewteMfdD32us40NDC',
#    'is_local': False,
#    'name': 'Nee Selvadigi',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/69032cb7a3465007eec6e415bbe921c040a53ab5?cid=92e85be5573c4fa0b92fe2b75bcc1256',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:14ZvcewteMfdD32us40NDC'}}]

# %%
tracks_df = pd.json_normalize(tracks['items'], record_path=['track', 'artists'], meta=[['added_at'], ['track', 'uri'], ['track', 'name']])
tracks_df = tracks_df.drop_duplicates(subset='track.uri', keep="first")
#[['added_at', 'track.uri','track.name']]
tracks_df['added_at'] = pd.to_datetime(tracks_df['added_at'])
tracks_df = tracks_df.sort_values(by='added_at', ascending=True).set_index('added_at')
tracks_df = tracks_df.last('3M')[['name', 'uri', 'track.uri', 'track.name']]
tracks_df.rename(columns={'track.uri':'uri', 'track.name': 'song', 'name': 'artist', 'uri': 'artist_uri'}, inplace=True)
tracks_df
# Out:
#                                     artist  \
# added_at
# 2021-07-27 01:09:07+00:00          Mithoon
# 2021-08-20 00:51:53+00:00          Karthik
# 2021-08-27 20:55:52+00:00          Karunya
# 2021-09-05 22:32:25+00:00  Imagine Dragons
#
#                                                       artist_uri  \
# added_at
# 2021-07-27 01:09:07+00:00  spotify:artist:09UmIX92EUH9hAK4bxvHx6
# 2021-08-20 00:51:53+00:00  spotify:artist:0LSPREIgGMZXCuKVel7LVD
# 2021-08-27 20:55:52+00:00  spotify:artist:6qrS6jqZfr8HJe3IWkQqv2
# 2021-09-05 22:32:25+00:00  spotify:artist:53XhwfbYqKCa1cC15pYq2q
#
#                                                             uri  \
# added_at
# 2021-07-27 01:09:07+00:00  spotify:track:7rMqbvNImA6wy8lxlNUMmj
# 2021-08-20 00:51:53+00:00  spotify:track:2OTWTkshnDUT3pKrf0ElOh
# 2021-08-27 20:55:52+00:00  spotify:track:59j1ZUoWtcJqiEycTmOl0d
# 2021-09-05 22:32:25+00:00  spotify:track:1lgN0A2Vki2FTON5PYq42m
#
#                                                                         song
# added_at
# 2021-07-27 01:09:07+00:00  Bolo Har Har Har (feat. Mohit Chauhan, Sukhwin...
# 2021-08-20 00:51:53+00:00                               Nuvvani Idhi Needani
# 2021-08-27 20:55:52+00:00                                     Ola Olaala Ala
# 2021-09-05 22:32:25+00:00                                           Warriors

# %%
tracks_df.iloc[2]['uri'] = 'fjdkk'
tracks_df
# Out:
#                                     artist  \
# added_at
# 2021-07-27 01:09:07+00:00          Mithoon
# 2021-08-20 00:51:53+00:00          Karthik
# 2021-08-27 20:55:52+00:00          Karunya
# 2021-09-05 22:32:25+00:00  Imagine Dragons
#
#                                                       artist_uri  \
# added_at
# 2021-07-27 01:09:07+00:00  spotify:artist:09UmIX92EUH9hAK4bxvHx6
# 2021-08-20 00:51:53+00:00  spotify:artist:0LSPREIgGMZXCuKVel7LVD
# 2021-08-27 20:55:52+00:00  spotify:artist:6qrS6jqZfr8HJe3IWkQqv2
# 2021-09-05 22:32:25+00:00  spotify:artist:53XhwfbYqKCa1cC15pYq2q
#
#                                                             uri  \
# added_at
# 2021-07-27 01:09:07+00:00  spotify:track:7rMqbvNImA6wy8lxlNUMmj
# 2021-08-20 00:51:53+00:00  spotify:track:2OTWTkshnDUT3pKrf0ElOh
# 2021-08-27 20:55:52+00:00                                 fjdkk
# 2021-09-05 22:32:25+00:00  spotify:track:1lgN0A2Vki2FTON5PYq42m
#
#                                                                         song
# added_at
# 2021-07-27 01:09:07+00:00  Bolo Har Har Har (feat. Mohit Chauhan, Sukhwin...
# 2021-08-20 00:51:53+00:00                               Nuvvani Idhi Needani
# 2021-08-27 20:55:52+00:00                                     Ola Olaala Ala
# 2021-09-05 22:32:25+00:00                                           Warriors

# %%
audio_feats = []
all_uris = tracks_df['uri'].tolist()
chunks_uris = [all_uris[i:i + 100] for i in range(0, len(all_uris), 100)]
for chunk in  chunks_uris:
   for attempt in range(10):
         try:
            chunk_audio_feats = sp.audio_features(chunk)
            audio_feats.append(chunk_audio_feats)
         except Exception as e: 
            print(e)
            print('chunk: {}'.format(chunk))
         else:
            break
   else:
         print('Everything failed')

all_audio_feats = [item for sublist in audio_feats for item in sublist if item]

# %%
audio_feats_df = pd.DataFrame(all_audio_feats)
audio_feats_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.598   0.813    9    -6.107     1       0.0660        0.2780
# 1         0.688   0.765    9    -4.883     0       0.0624        0.6490
# 2         0.365   0.851    4    -6.238     0       0.0650        0.0964
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1090    0.311  140.101  audio_features
# 1          0.000014    0.0712    0.410  100.016  audio_features
# 2          0.003000    0.2380    0.309   78.068  audio_features
#
#                        id                                   uri  \
# 0  7rMqbvNImA6wy8lxlNUMmj  spotify:track:7rMqbvNImA6wy8lxlNUMmj
# 1  2OTWTkshnDUT3pKrf0ElOh  spotify:track:2OTWTkshnDUT3pKrf0ElOh
# 2  1lgN0A2Vki2FTON5PYq42m  spotify:track:1lgN0A2Vki2FTON5PYq42m
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7rMqbvNImA6w...
# 1  https://api.spotify.com/v1/tracks/2OTWTkshnDUT...
# 2  https://api.spotify.com/v1/tracks/1lgN0A2Vki2F...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7rMq...       294331
# 1  https://api.spotify.com/v1/audio-analysis/2OTW...       260700
# 2  https://api.spotify.com/v1/audio-analysis/1lgN...       170067
#
#    time_signature
# 0               4
# 1               4
# 2               4

# %%
fav_songs_feats_df = tracks_df.merge(audio_feats_df, how='right', on="uri")
fav_songs_feats_df
# Out:
#             artist                             artist_uri  \
# 0          Mithoon  spotify:artist:09UmIX92EUH9hAK4bxvHx6
# 1          Karthik  spotify:artist:0LSPREIgGMZXCuKVel7LVD
# 2  Imagine Dragons  spotify:artist:53XhwfbYqKCa1cC15pYq2q
#
#                                     uri  \
# 0  spotify:track:7rMqbvNImA6wy8lxlNUMmj
# 1  spotify:track:2OTWTkshnDUT3pKrf0ElOh
# 2  spotify:track:1lgN0A2Vki2FTON5PYq42m
#
#                                                 song  danceability  energy  \
# 0  Bolo Har Har Har (feat. Mohit Chauhan, Sukhwin...         0.598   0.813
# 1                               Nuvvani Idhi Needani         0.688   0.765
# 2                                           Warriors         0.365   0.851
#
#    key  loudness  mode  speechiness  ...  instrumentalness  liveness  valence  \
# 0    9    -6.107     1       0.0660  ...          0.000000    0.1090    0.311
# 1    9    -4.883     0       0.0624  ...          0.000014    0.0712    0.410
# 2    4    -6.238     0       0.0650  ...          0.003000    0.2380    0.309
#
#      tempo            type                      id  \
# 0  140.101  audio_features  7rMqbvNImA6wy8lxlNUMmj
# 1  100.016  audio_features  2OTWTkshnDUT3pKrf0ElOh
# 2   78.068  audio_features  1lgN0A2Vki2FTON5PYq42m
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7rMqbvNImA6w...
# 1  https://api.spotify.com/v1/tracks/2OTWTkshnDUT...
# 2  https://api.spotify.com/v1/tracks/1lgN0A2Vki2F...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7rMq...      294331
# 1  https://api.spotify.com/v1/audio-analysis/2OTW...      260700
# 2  https://api.spotify.com/v1/audio-analysis/1lgN...      170067
#
#    time_signature
# 0               4
# 1               4
# 2               4
#
# [3 rows x 21 columns]
